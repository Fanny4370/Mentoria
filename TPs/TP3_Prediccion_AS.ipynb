# %% [markdown]
# # DiploDatos 2026- Mentoría "Deteccion de fraude: ¿Como cuido a mis clientes? Machine Learning aplicado a un caso de negocio financiero"

# %% [markdown]
# ## <font color=blue> Trabajo Practico N° 3
#
# ## Mentoría "Deteccion de fraude: ¿Como cuido a mis clientes? Machine Learning aplicado a un caso de negocio financiero"

# %% [markdown]
# ## Aprendizaje Supervisado
#
# ### Entregable
# ● Los invito a desarrollar cada punto en la Notebook compartida que les sirve de guía para cumplir con este TP.
#
# ● Se debe subir el entregable a un repositorio GitHub o enviar el link a un Google Colab.
#
# ● Si bien seguramente se harán muchos análisis de diversos tipos y consideraciones, solo se debe dejar en la Notebook a entregar aquellos análisis que sean relevantes y que consideren de importancia según el tema a presentar.
#
# ● Recuerden siempre que luego de cada gráfico, cálculo, es importante describir brevemente que es lo que se está haciendo, y si son gráficos, a que conclusión han llegado, para expresar los comprendido y el nivel de profundidad alcanzada de los contenidos teóricos impartidos.

# %% [markdown]
# ### Input
# Se deberá considerar como input para esta Notebook el df obtenido del práctico anterior, el cual ya se encuentra limpio, sin nulos, cuyas variables ya tuvieron análisis de correlación, etc.
# Se deberá realizar un breve análisis descriptivo y exploratorio de las variables contenidas, sumar lo ya aprendido en los TP1 Y TP2, y aplicar los distintos métodos y técnicas aprendido en clases haciendo foco en la ejecución de los mismos, más allá de los resultados que se puedan obtener, lo esencial es comprender los pasos que son necesarios realizar para el buen desarrollo del modelo.

# %% [markdown]
# ### Preparación de los datos para aplicar modelos de clasificacion.
#
# Generar a partir del dataset, los conjuntos de datos *train*, *test* y *validation*.
#
# Analizar las proporciones consideradas para cada conjunto con respecto al total del dataset. Verificar el total de datos de cada conjunto.
#
# Para cada conjunto (train, test, val), ¿cuántos datos de cada clase hay (Fraude y No Fraude)?, se debe buscar mantener la proporción del dataset total.

# %% [markdown]
# ### Creación de un modelo baseline
#
# Entrenar un modelo “baseline”, es decir lo más simple posible, para con ello tener un punto de partida con el cual comparar modelos más complejos. Consejo se puede iniciar usando por ejemplo la clase “DummyClassifier” de scikit-learn, pueden fijar la semilla alieatoria para poder repetir el ejercicio
#
# Evaluar sobre el conjunto de entrenamiento, validación y test reportando:
# 1. Accuracy
# 2. Precision
# 3. Recall
# 4. F1
# 5. Matriz de confusión
#
# Pensar cuál métrica es conveniente optimizar en éste problema de clasificación donde se predice el Fraude. ¿Sería el Accuracy una buena métrica?
# Documentación:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html

# %% [markdown]
# #### Predicción de modelos lineales
#
# Aqui deberan realizar el entrenamiento de los modelos lineales de clasificación para predecir la variable objetivo. Utilizando  “LogisticRegression” de scikit-learn y deberan elegir al menos uno de los siguientes otros modelos:
#
# La clase SGDClassifier de scikit-learn.
#
# La clase LinearSVC de scikit-learn.
#
# Documentación:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# https://scikit-learn.org/stable/modules/sgd.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html
#
# Recordar fijar la semilla aleatoria para hacer repetible el experimento.
#
# De la misma forma que en el apartado anterior se debera evaluar sobre el conjunto de entrenamiento, validación y test reportando:
#
# Accuracy
#
# Precision
#
# Recall
#
# F1
#
# Matriz de confusión
#
# Elabore conclusiones en base a la métrica a optimizar y compare con el modelo baseline.

# %% [markdown]
# #### Predicción de modelos basados en árboles de decisión
# Deberán elegir al menos dos de los siguientes modelos o proponga 2 que considere que mejor se adaptan al caso de estudio:
#
# La clase DecisionTreeClassifier de scikit-learn.
#
# La clase RandomForestClassifier de scikit-learn.
#
# La clase GradientBoostingClassifier de scikit-learn.
#
# Recordar, fijar la semilla aleatoria para hacer repetible el experimento.
#
# Evaluar sobre el conjunto de entrenamiento, validación y test reportando:
#
# Accuracy
#
# Precision
#
# Recall
#
# F1
#
# Matriz de confusión
#
# Elabore conclusiones en base a la métrica a optimizar, comparando los modelos elegidos y contrastando con el modelo lineal elegido.
#
#
# Documentación:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html

# %% [markdown]
# #### Ajuste por hiperparámetros
# Para los dos “mejores modelos” obtenidos en los puntos anteriores, seleccionar valores para los hiperparámetros principales de dichos modelos
# (ajustar con por lo menos 3 parámetros). Utilizar grid-search y k-fold cross-validation.
#
# Analizar cual fue el mejor modelo obtenido de la Optimización de Hiperparámetros y con cuáles parámetros se obtuvo ese resultado.
#
# Con el mejor modelo obtenido realizar las predicciones sobre test y val.
#
# Reportar las métricas del mejor modelo, incluyendo las matrices de confusión. Comparar el mejor modelo obtenido, con el modelo con parámetros por defecto y con el modelo baseline. Elabore conclusiones al respecto pensando en la resolución de nuestro problema de deteccion de fraude.
